# %%
import os
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

# %%
os.listdir()
# Out:
# ['.ipynb_checkpoints',
#  'car data.csv',
#  'DATA_ANALYSIS_USED_CARS_KF.ipynb',
#  'Untitled.ipynb',
#  'USED_CARS_KF.ipynb',
#  'used_cars_prediction-main']

# %%
df=pd.read_csv('car data.csv')

# %%
df.head()
# Out:
#   Car_Name  Year  Selling_Price  Present_Price  Kms_Driven Fuel_Type  \
# 0     ritz  2014           3.35           5.59       27000    Petrol
# 1      sx4  2013           4.75           9.54       43000    Diesel
# 2     ciaz  2017           7.25           9.85        6900    Petrol
# 3  wagon r  2011           2.85           4.15        5200    Petrol
# 4    swift  2014           4.60           6.87       42450    Diesel
#
#   Seller_Type Transmission  Owner
# 0      Dealer       Manual      0
# 1      Dealer       Manual      0
# 2      Dealer       Manual      0
# 3      Dealer       Manual      0
# 4      Dealer       Manual      0

# %%
df.tail()
# Out:
#     Car_Name  Year  Selling_Price  Present_Price  Kms_Driven Fuel_Type  \
# 296     city  2016           9.50           11.6       33988    Diesel
# 297     brio  2015           4.00            5.9       60000    Petrol
# 298     city  2009           3.35           11.0       87934    Petrol
# 299     city  2017          11.50           12.5        9000    Diesel
# 300     brio  2016           5.30            5.9        5464    Petrol
#
#     Seller_Type Transmission  Owner
# 296      Dealer       Manual      0
# 297      Dealer       Manual      0
# 298      Dealer       Manual      0
# 299      Dealer       Manual      0
# 300      Dealer       Manual      0

# %%
df.shape
# Out:
# (301, 9)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 301 entries, 0 to 300
# Data columns (total 9 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Car_Name       301 non-null    object
#  1   Year           301 non-null    int64
#  2   Selling_Price  301 non-null    float64
#  3   Present_Price  301 non-null    float64
#  4   Kms_Driven     301 non-null    int64
#  5   Fuel_Type      301 non-null    object
#  6   Seller_Type    301 non-null    object
#  7   Transmission   301 non-null    object
#  8   Owner          301 non-null    int64
# dtypes: float64(2), int64(3), object(4)
# memory usage: 21.3+ KB

# %%
df.columns
# Out:
# Index(['Car_Name', 'Year', 'Selling_Price', 'Present_Price', 'Kms_Driven',
#        'Fuel_Type', 'Seller_Type', 'Transmission', 'Owner'],
#       dtype='object')

# %%
df.index
# Out:
# RangeIndex(start=0, stop=301, step=1)

# %%
df.values
# Out:
# array([['ritz', 2014, 3.35, ..., 'Dealer', 'Manual', 0],
#        ['sx4', 2013, 4.75, ..., 'Dealer', 'Manual', 0],
#        ['ciaz', 2017, 7.25, ..., 'Dealer', 'Manual', 0],
#        ...,
#        ['city', 2009, 3.35, ..., 'Dealer', 'Manual', 0],
#        ['city', 2017, 11.5, ..., 'Dealer', 'Manual', 0],
#        ['brio', 2016, 5.3, ..., 'Dealer', 'Manual', 0]], dtype=object)

# %%
df.describe()
# Out:
#               Year  Selling_Price  Present_Price     Kms_Driven       Owner
# count   301.000000     301.000000     301.000000     301.000000  301.000000
# mean   2013.627907       4.661296       7.628472   36947.205980    0.043189
# std       2.891554       5.082812       8.644115   38886.883882    0.247915
# min    2003.000000       0.100000       0.320000     500.000000    0.000000
# 25%    2012.000000       0.900000       1.200000   15000.000000    0.000000
# 50%    2014.000000       3.600000       6.400000   32000.000000    0.000000
# 75%    2016.000000       6.000000       9.900000   48767.000000    0.000000
# max    2018.000000      35.000000      92.600000  500000.000000    3.000000

# %%
df.head()
# Out:
#   Car_Name  Year  Selling_Price  Present_Price  Kms_Driven Fuel_Type  \
# 0     ritz  2014           3.35           5.59       27000    Petrol
# 1      sx4  2013           4.75           9.54       43000    Diesel
# 2     ciaz  2017           7.25           9.85        6900    Petrol
# 3  wagon r  2011           2.85           4.15        5200    Petrol
# 4    swift  2014           4.60           6.87       42450    Diesel
#
#   Seller_Type Transmission  Owner
# 0      Dealer       Manual      0
# 1      Dealer       Manual      0
# 2      Dealer       Manual      0
# 3      Dealer       Manual      0
# 4      Dealer       Manual      0

# %%
df.dtypes
# Out:
# Car_Name          object
# Year               int64
# Selling_Price    float64
# Present_Price    float64
# Kms_Driven         int64
# Fuel_Type         object
# Seller_Type       object
# Transmission      object
# Owner              int64
# dtype: object

# %%
df.sort_index(axis=1,ascending=True)#aplabetical order
# Out:
#     Car_Name Fuel_Type  Kms_Driven  Owner  Present_Price Seller_Type  \
# 0       ritz    Petrol       27000      0           5.59      Dealer
# 1        sx4    Diesel       43000      0           9.54      Dealer
# 2       ciaz    Petrol        6900      0           9.85      Dealer
# 3    wagon r    Petrol        5200      0           4.15      Dealer
# 4      swift    Diesel       42450      0           6.87      Dealer
# ..       ...       ...         ...    ...            ...         ...
# 296     city    Diesel       33988      0          11.60      Dealer
# 297     brio    Petrol       60000      0           5.90      Dealer
# 298     city    Petrol       87934      0          11.00      Dealer
# 299     city    Diesel        9000      0          12.50      Dealer
# 300     brio    Petrol        5464      0           5.90      Dealer
#
#      Selling_Price Transmission  Year
# 0             3.35       Manual  2014
# 1             4.75       Manual  2013
# ...

# %%
df.head(2)
# Out:
#   Car_Name  Year  Selling_Price  Present_Price  Kms_Driven Fuel_Type  \
# 0     ritz  2014           3.35           5.59       27000    Petrol
# 1      sx4  2013           4.75           9.54       43000    Diesel
#
#   Seller_Type Transmission  Owner
# 0      Dealer       Manual      0
# 1      Dealer       Manual      0

# %%
df.sort_values(by='Kms_Driven')# sorting as per kms driven, 
df.sort_values(by='Kms_Driven',ascending=False)#sorting as per descending order
# Out:
#               Car_Name  Year  Selling_Price  Present_Price  Kms_Driven  \
# 196          Activa 3g  2008           0.17           0.52      500000
# 179      Honda Karizma  2010           0.31           1.05      213000
# 84              innova  2005           3.49          13.46      197176
# 85               camry  2006           2.50          23.73      142000
# 77             corolla  2004           1.50          12.35      135154
# ..                 ...   ...            ...            ...         ...
# 126  Bajaj Avenger 220  2017           0.90           0.95        1300
# 103  Bajaj Dominar 400  2017           1.45           1.60        1200
# 166   Hero Passion Pro  2016           0.45           0.55        1000
# 165          Activa 3g  2016           0.45           0.54         500
# 133  Bajaj Avenger 220  2016           0.72           0.95         500
#
#     Fuel_Type Seller_Type Transmission  Owner
# 196    Petrol  Individual    Automatic      0
# ...

# %%
df['Car_Name'] #selecting a single column
# Out:
# 0         ritz
# 1          sx4
# 2         ciaz
# 3      wagon r
# 4        swift
#         ...
# 296       city
# 297       brio
# 298       city
# 299       city
# 300       brio
# Name: Car_Name, Length: 301, dtype: object

# %%
df[2:6]# selecting multiples rows and columns  via [],using slices
# Out:
#         Car_Name  Year  Selling_Price  Present_Price  Kms_Driven Fuel_Type  \
# 2           ciaz  2017           7.25           9.85        6900    Petrol
# 3        wagon r  2011           2.85           4.15        5200    Petrol
# 4          swift  2014           4.60           6.87       42450    Diesel
# 5  vitara brezza  2018           9.25           9.83        2071    Diesel
#
#   Seller_Type Transmission  Owner
# 2      Dealer       Manual      0
# 3      Dealer       Manual      0
# 4      Dealer       Manual      0
# 5      Dealer       Manual      0

# %%
df[50:70] #getting middle rows and columns using slicing
# Out:
#          Car_Name  Year  Selling_Price  Present_Price  Kms_Driven Fuel_Type  \
# 50       fortuner  2012          14.90          30.61      104707    Diesel
# 51       fortuner  2015          23.00          30.61       40000    Diesel
# 52         innova  2017          18.00          19.77       15000    Diesel
# 53       fortuner  2013          16.00          30.61      135000    Diesel
# 54         innova  2005           2.75          10.21       90000    Petrol
# 55  corolla altis  2009           3.60          15.04       70000    Petrol
# 56    etios cross  2015           4.50           7.27       40534    Petrol
# 57  corolla altis  2010           4.75          18.54       50000    Petrol
# 58        etios g  2014           4.10           6.80       39485    Petrol
# 59       fortuner  2014          19.99          35.96       41000    Diesel
# 60  corolla altis  2013           6.95          18.61       40001    Petrol
# ...

# %%
df.loc[2]
# Out:
# Car_Name           ciaz
# Year               2017
# Selling_Price      7.25
# Present_Price      9.85
# Kms_Driven         6900
# Fuel_Type        Petrol
# Seller_Type      Dealer
# Transmission     Manual
# Owner                 0
# Name: 2, dtype: object

# %%
df.loc[2]
# Out:
# Car_Name           ciaz
# Year               2017
# Selling_Price      7.25
# Present_Price      9.85
# Kms_Driven         6900
# Fuel_Type        Petrol
# Seller_Type      Dealer
# Transmission     Manual
# Owner                 0
# Name: 2, dtype: object

# %%
df.loc[67]# select via position
# Out:
# Car_Name         fortuner
# Year                 2010
# Selling_Price        9.25
# Present_Price       20.45
# Kms_Driven          59000
# Fuel_Type          Diesel
# Seller_Type        Dealer
# Transmission       Manual
# Owner                   0
# Name: 67, dtype: object

# %%
df.iloc[3:7,3:5] # by slicing of rows and columns
# Out:
#    Present_Price  Kms_Driven
# 3           4.15        5200
# 4           6.87       42450
# 5           9.83        2071
# 6           8.12       18796

# %%
df.iloc[[1,2,4],[0,2]]# by list of integer position locations
# Out:
#   Car_Name  Selling_Price
# 1      sx4           4.75
# 2     ciaz           7.25
# 4    swift           4.60

# %%
df.iloc[5:30,:]# for slicing rows explicitly
# Out:
#          Car_Name  Year  Selling_Price  Present_Price  Kms_Driven Fuel_Type  \
# 5   vitara brezza  2018           9.25           9.83        2071    Diesel
# 6            ciaz  2015           6.75           8.12       18796    Petrol
# 7         s cross  2015           6.50           8.61       33429    Diesel
# 8            ciaz  2016           8.75           8.89       20273    Diesel
# 9            ciaz  2015           7.45           8.92       42367    Diesel
# 10       alto 800  2017           2.85           3.60        2135    Petrol
# 11           ciaz  2015           6.85          10.38       51000    Diesel
# 12           ciaz  2015           7.50           9.94       15000    Petrol
# 13         ertiga  2015           6.10           7.71       26000    Petrol
# 14          dzire  2009           2.25           7.21       77427    Petrol
# 15         ertiga  2016           7.75          10.79       43000    Diesel
# ...

# %%
df.iloc[:,1:5]# for slicing columns explicitly
# Out:
#      Year  Selling_Price  Present_Price  Kms_Driven
# 0    2014           3.35           5.59       27000
# 1    2013           4.75           9.54       43000
# 2    2017           7.25           9.85        6900
# 3    2011           2.85           4.15        5200
# 4    2014           4.60           6.87       42450
# ..    ...            ...            ...         ...
# 296  2016           9.50          11.60       33988
# 297  2015           4.00           5.90       60000
# 298  2009           3.35          11.00       87934
# 299  2017          11.50          12.50        9000
# 300  2016           5.30           5.90        5464
#
# [301 rows x 4 columns]

# %%
df.iloc[5,2]# for getting a  value explicitly
# Out:
# 9.25

# %%
#BOOLEAN INDEXING 
df[df.Selling_Price > 6] #using a single columns values to select data with a condition
# Out:
#           Car_Name  Year  Selling_Price  Present_Price  Kms_Driven Fuel_Type  \
# 2             ciaz  2017           7.25           9.85        6900    Petrol
# 5    vitara brezza  2018           9.25           9.83        2071    Diesel
# 6             ciaz  2015           6.75           8.12       18796    Petrol
# 7          s cross  2015           6.50           8.61       33429    Diesel
# 8             ciaz  2016           8.75           8.89       20273    Diesel
# ..             ...   ...            ...            ...         ...       ...
# 289           city  2016          10.11          13.60       10980    Petrol
# 292           jazz  2016           6.40           8.40       12000    Petrol
# 295           city  2015           8.55          13.09       60076    Diesel
# 296           city  2016           9.50          11.60       33988    Diesel
# 299           city  2017          11.50          12.50        9000    Diesel
#
#     Seller_Type Transmission  Owner
# ...

# %%
#usinf is in ()method for filtering
df_1=df.copy()

# %%
#df_1['new_cars']=['kia','kia_seltos','kia_sedan','kia_suv']#getting error

# %%
df_1.dropna(how='any')
# Out:
#     Car_Name  Year  Selling_Price  Present_Price  Kms_Driven Fuel_Type  \
# 0       ritz  2014           3.35           5.59       27000    Petrol
# 1        sx4  2013           4.75           9.54       43000    Diesel
# 2       ciaz  2017           7.25           9.85        6900    Petrol
# 3    wagon r  2011           2.85           4.15        5200    Petrol
# 4      swift  2014           4.60           6.87       42450    Diesel
# ..       ...   ...            ...            ...         ...       ...
# 296     city  2016           9.50          11.60       33988    Diesel
# 297     brio  2015           4.00           5.90       60000    Petrol
# 298     city  2009           3.35          11.00       87934    Petrol
# 299     city  2017          11.50          12.50        9000    Diesel
# 300     brio  2016           5.30           5.90        5464    Petrol
#
#     Seller_Type Transmission  Owner
# 0        Dealer       Manual      0
# 1        Dealer       Manual      0
# ...

# %%
df_1.fillna(value=5)#filling the na values with 5
# Out:
#     Car_Name  Year  Selling_Price  Present_Price  Kms_Driven Fuel_Type  \
# 0       ritz  2014           3.35           5.59       27000    Petrol
# 1        sx4  2013           4.75           9.54       43000    Diesel
# 2       ciaz  2017           7.25           9.85        6900    Petrol
# 3    wagon r  2011           2.85           4.15        5200    Petrol
# 4      swift  2014           4.60           6.87       42450    Diesel
# ..       ...   ...            ...            ...         ...       ...
# 296     city  2016           9.50          11.60       33988    Diesel
# 297     brio  2015           4.00           5.90       60000    Petrol
# 298     city  2009           3.35          11.00       87934    Petrol
# 299     city  2017          11.50          12.50        9000    Diesel
# 300     brio  2016           5.30           5.90        5464    Petrol
#
#     Seller_Type Transmission  Owner
# 0        Dealer       Manual      0
# 1        Dealer       Manual      0
# ...

# %%
pd.isnull(df_1)
# Out:
#      Car_Name   Year  Selling_Price  Present_Price  Kms_Driven  Fuel_Type  \
# 0       False  False          False          False       False      False
# 1       False  False          False          False       False      False
# 2       False  False          False          False       False      False
# 3       False  False          False          False       False      False
# 4       False  False          False          False       False      False
# ..        ...    ...            ...            ...         ...        ...
# 296     False  False          False          False       False      False
# 297     False  False          False          False       False      False
# 298     False  False          False          False       False      False
# 299     False  False          False          False       False      False
# 300     False  False          False          False       False      False
#
#      Seller_Type  Transmission  Owner
# 0          False         False  False
# ...

# %%
#OPERATIONS
df.mean()
# Out:
# Year              2013.627907
# Selling_Price        4.661296
# Present_Price        7.628472
# Kms_Driven       36947.205980
# Owner                0.043189
# dtype: float64

# %%
df.median()
# Out:
# Year              2014.0
# Selling_Price        3.6
# Present_Price        6.4
# Kms_Driven       32000.0
# Owner                0.0
# dtype: float64

# %%
df.corr()
# Out:
#                    Year  Selling_Price  Present_Price  Kms_Driven     Owner
# Year           1.000000       0.236141      -0.047584   -0.524342 -0.182104
# Selling_Price  0.236141       1.000000       0.878983    0.029187 -0.088344
# Present_Price -0.047584       0.878983       1.000000    0.203647  0.008057
# Kms_Driven    -0.524342       0.029187       0.203647    1.000000  0.089216
# Owner         -0.182104      -0.088344       0.008057    0.089216  1.000000

# %%
df.std()
# Out:
# Year                 2.891554
# Selling_Price        5.082812
# Present_Price        8.644115
# Kms_Driven       38886.883882
# Owner                0.247915
# dtype: float64

# %%
df.var()
# Out:
# Year             8.361085e+00
# Selling_Price    2.583497e+01
# Present_Price    7.472073e+01
# Kms_Driven       1.512190e+09
# Owner            6.146179e-02
# dtype: float64

# %%
df.cumsum()
# Out:
#                                               Car_Name    Year  Selling_Price  \
# 0                                                 ritz    2014           3.35
# 1                                              ritzsx4    4027           8.10
# 2                                          ritzsx4ciaz    6044          15.35
# 3                                   ritzsx4ciazwagon r    8055          18.20
# 4                              ritzsx4ciazwagon rswift   10069          22.80
# ..                                                 ...     ...            ...
# 296  ritzsx4ciazwagon rswiftvitara brezzaciazs cros...  598045        1378.90
# 297  ritzsx4ciazwagon rswiftvitara brezzaciazs cros...  600060        1382.90
# 298  ritzsx4ciazwagon rswiftvitara brezzaciazs cros...  602069        1386.25
# 299  ritzsx4ciazwagon rswiftvitara brezzaciazs cros...  604086        1397.75
# 300  ritzsx4ciazwagon rswiftvitara brezzaciazs cros...  606102        1403.05
#
# ...

# %%
df.groupby('Kms_Driven').sum()
# Out:
#             Year  Selling_Price  Present_Price  Owner
# Kms_Driven
# 500         4032           1.17           1.49      0
# 1000        2016           0.45           0.55      0
# 1200        2017           1.45           1.60      0
# 1300        4034           1.30           1.46      0
# 1400        2017           1.70           1.82      0
# ...          ...            ...            ...    ...
# 135154      2004           1.50          12.35      0
# 142000      2006           2.50          23.73      3
# 197176      2005           3.49          13.46      0
# 213000      2010           0.31           1.05      0
# 500000      2008           0.17           0.52      0
#
# [206 rows x 4 columns]

# %%
df.groupby('Fuel_Type').sum()
# Out:
#              Year  Selling_Price  Present_Price  Kms_Driven  Owner
# Fuel_Type
# CNG          4026           6.20          12.83       85498      0
# Diesel     120840         616.71         948.87     3022195      1
# Petrol     481236         780.14        1334.47     8013416     12

# %%
df.groupby('Year').sum()
# Out:
#       Selling_Price  Present_Price  Kms_Driven  Owner
# Year
# 2003           2.60         10.260      189000      0
# 2004           1.50         12.350      135154      0
# 2005           9.95         37.940      417176      0
# 2006           5.75         36.230      349689      3
# 2007           0.32          1.330      102000      1
# 2008           7.02         33.317      784900      1
# 2009          16.90         63.610      406923      0
# 2010          78.94        214.960      900211      1
# 2011          45.13         97.813      766220      1
# 2012          88.35        183.650     1007359      1
# 2013         116.85        225.097     1370633      1
# 2014         180.96        297.843     1447052      2
# 2015         361.55        499.100     1958661      1
# 2016         260.66        327.540      919367      1
# 2017         217.32        245.300      364693      0
# 2018           9.25          9.830        2071      0

# %%
df.groupby('Seller_Type').sum()
# Out:
#                Year  Selling_Price  Present_Price  Kms_Driven  Owner
# Seller_Type
# Dealer       392674        1310.73        2122.83     7770776      4
# Individual   213428          92.32         173.34     3350333      9

# %%
df.groupby('Transmission').sum()
# Out:
#                 Year  Selling_Price  Present_Price  Kms_Driven  Owner
# Transmission
# Automatic      80545         376.80         612.62     2122519      3
# Manual        525557        1026.25        1683.55     8998590     10

# %%
df.groupby('Present_Price').sum()
# Out:
#                 Year  Selling_Price  Kms_Driven  Owner
# Present_Price
# 0.32            2015           0.18       35000      0
# 0.47            2013           0.27       21000      0
# 0.48            2016           0.30       50000      0
# 0.51           12086           2.04      134600      0
# 0.52            8049           1.25      556000      0
# ...              ...            ...         ...    ...
# 25.39           4033          43.75       44000      0
# 30.61          10067          91.40      408707      0
# 35.96           6043          62.24      166000      0
# 36.23           2017          33.00        6000      0
# 92.60           2010          35.00       78000      0
#
# [147 rows x 4 columns]

# %%
df.groupby(['Year','Fuel_Type']).sum()
# Out:
#                 Selling_Price  Present_Price  Kms_Driven  Owner
# Year Fuel_Type
# 2003 Petrol              2.60         10.260      189000      0
# 2004 Petrol              1.50         12.350      135154      0
# 2005 Diesel              3.49         13.460      197176      0
#      Petrol              6.46         24.480      220000      0
# 2006 Petrol              5.75         36.230      349689      3
# 2007 Petrol              0.32          1.330      102000      1
# 2008 Petrol              7.02         33.317      784900      1
# 2009 Petrol             16.90         63.610      406923      0
# 2010 Diesel             57.15        140.290      245024      1
#      Petrol             21.79         74.670      655187      0
# 2011 CNG                 2.95          7.740       49998      0
#      Diesel              4.50         12.480       45000      0
#      Petrol             37.68         77.593      671222      1
# ...

# %%
df.head(1)
# Out:
#   Car_Name  Year  Selling_Price  Present_Price  Kms_Driven Fuel_Type  \
# 0     ritz  2014           3.35           5.59       27000    Petrol
#
#   Seller_Type Transmission  Owner
# 0      Dealer       Manual      0

# %%
df.plot()
# Out:
# <AxesSubplot:>

# %%
plt.figure();

# %%
plt.legend(loc='best')
# Out:
# No handles with labels found to put in legend.

# %%
df.count()
# Out:
# Car_Name         301
# Year             301
# Selling_Price    301
# Present_Price    301
# Kms_Driven       301
# Fuel_Type        301
# Seller_Type      301
# Transmission     301
# Owner            301
# dtype: int64

# %%
df.max()
# Out:
# Car_Name              xcent
# Year                   2018
# Selling_Price          35.0
# Present_Price          92.6
# Kms_Driven           500000
# Fuel_Type            Petrol
# Seller_Type      Individual
# Transmission         Manual
# Owner                     3
# dtype: object

# %%
df.min()
# Out:
# Car_Name               800
# Year                  2003
# Selling_Price          0.1
# Present_Price         0.32
# Kms_Driven             500
# Fuel_Type              CNG
# Seller_Type         Dealer
# Transmission     Automatic
# Owner                    0
# dtype: object

# %%
df.mean()
# Out:
# Year              2013.627907
# Selling_Price        4.661296
# Present_Price        7.628472
# Kms_Driven       36947.205980
# Owner                0.043189
# dtype: float64

# %%
df.median()
# Out:
# Year              2014.0
# Selling_Price        3.6
# Present_Price        6.4
# Kms_Driven       32000.0
# Owner                0.0
# dtype: float64

# %%
df[1:]
# Out:
#           Car_Name  Year  Selling_Price  Present_Price  Kms_Driven Fuel_Type  \
# 1              sx4  2013           4.75           9.54       43000    Diesel
# 2             ciaz  2017           7.25           9.85        6900    Petrol
# 3          wagon r  2011           2.85           4.15        5200    Petrol
# 4            swift  2014           4.60           6.87       42450    Diesel
# 5    vitara brezza  2018           9.25           9.83        2071    Diesel
# ..             ...   ...            ...            ...         ...       ...
# 296           city  2016           9.50          11.60       33988    Diesel
# 297           brio  2015           4.00           5.90       60000    Petrol
# 298           city  2009           3.35          11.00       87934    Petrol
# 299           city  2017          11.50          12.50        9000    Diesel
# 300           brio  2016           5.30           5.90        5464    Petrol
#
#     Seller_Type Transmission  Owner
# ...

# %%
df.hist()
# Out:
# array([[<AxesSubplot:title={'center':'Year'}>,
#         <AxesSubplot:title={'center':'Selling_Price'}>],
#        [<AxesSubplot:title={'center':'Present_Price'}>,
#         <AxesSubplot:title={'center':'Kms_Driven'}>],
#        [<AxesSubplot:title={'center':'Owner'}>, <AxesSubplot:>]],
#       dtype=object)

# %%
df.skew()
# Out:
# Year            -1.246189
# Selling_Price    2.493422
# Present_Price    4.083150
# Kms_Driven       6.436013
# Owner            7.616850
# dtype: float64

# %%
df.duplicated().any()
# Out:
# True

# %%
'''for col in df.columns:
    df[[col]].boxplot()
    plt.show()'''
# Out:
# 'for col in df.columns:\n    df[[col]].boxplot()\n    plt.show()'

# %%
df.hist(figsize=(10,10),edgecolor="k")# for  plotting all the historams together
plt.tight_layout()
plt.show()

# %%
df.hist()
# Out:
# array([[<AxesSubplot:title={'center':'Year'}>,
#         <AxesSubplot:title={'center':'Selling_Price'}>],
#        [<AxesSubplot:title={'center':'Present_Price'}>,
#         <AxesSubplot:title={'center':'Kms_Driven'}>],
#        [<AxesSubplot:title={'center':'Owner'}>, <AxesSubplot:>]],
#       dtype=object)

# %%
plt.bar('Car_Name','Fuel_Type')
plt.show()
Car_Name=df['Car_Name'].value_counts().keys()
Fuel_Type=df['Fuel_Type'].value_counts().tolist()

# %%
df.head(1)
# Out:
#   Car_Name  Year  Selling_Price  Present_Price  Kms_Driven Fuel_Type  \
# 0     ritz  2014           3.35           5.59       27000    Petrol
#
#   Seller_Type Transmission  Owner
# 0      Dealer       Manual      0
